# %% [markdown]
# # 📘 Contrôle S1 : fondamentaux Python et TAL
#
# ## 🎯 Objectifs du contrôle
#
# Ce contrôle évalue votre maîtrise des structures de base (listes, dictionnaires, boucles, fonctions) et de la **rigueur algorithmique** (syntaxe, logique, distinction `print`/`return`). Chaque question contient un **fragment de code erroné ou incomplet** que vous devez corriger ou compléter pour obtenir la sortie demandée.
#
# ## ⚙️ Instructions générales
#
# 1.  **Identification :** complétez la cellule 0.1.
# 2.  **Correction :** Pour les questions de calcul, modifiez uniquement les lignes de code nécessaires pour obtenir le résultat affiché dans le `print` final. Ne modifiez PAS les lignes de `print` elles-mêmes.
# 3.  **Exécution :** Exécutez TOUTES les cellules dans l'ordre.
#
# ## ❌ Conditions conseil : pas d'IA, pas de web

# %% [markdown]
# ### **0.1 : Identification (1.0 pt)**

# %%
# Complétez les informations entre les guillemets.
nom = "d"
prenom = "r"
classe = "M1-TILT-2027"

# %% [markdown]
# ---
# ## Partie 1 : Variables, types et chaînes (5 Q - 5.0 pts)

# %% [markdown]
# ### **Question 1 : correction de type (1.0 pt)**
# Corrigez la `TypeError` pour que le code calcule le coût correctement (3000 mots à 0.05€) et affiche `Coût total : 150.0 €`.

# %%
nb_mots = "3000"
taux_unitaire = 0.05

# CORRECTION REQUISE (LIGNE SUIVANTE)
cout_total = int(nb_mots) * taux_unitaire

valeur_Q1 = cout_total
print(f"Résultat Q1 : Coût total : {valeur_Q1} €")
# Out:
# Résultat Q1 : Coût total : 150.0 €

# %% [markdown]
# ### **Question 2 : indexation et slicing (1.0 pt)**
# Utilisez le *slicing* pour extraire et stocker le mot `'extraction'` dans la variable `valeur_Q2`.

# %%
corpus_brut = "TAL : la clé est l'extraction terminologique."

# CORRECTION REQUISE (LIGNE SUIVANTE)
valeur_Q2_deb = 19
valeur_Q2_fin = 29
mot_extrait = corpus_brut[valeur_Q2_deb:valeur_Q2_fin]
print(f"Résultat Q2 : Le mot extrait est '{mot_extrait}' (Indices {valeur_Q2_deb}:{valeur_Q2_fin})")
# Out:
# Résultat Q2 : Le mot extrait est '' (Indices 0:0)

# %% [markdown]
# ### **Question 3 : rigueur syntaxique (1.0 pt)**
# Le code contient une erreur de syntaxe. Corrigez la ligne du `if` pour que la variable `valeur_Q3` soit égale à `True`.

# %%
note = 12
seuil = 10

# CORRECTION REQUISE (LIGNE SUIVANTE)
if note >= seuil:
    valeur_Q3 = True
else:
    valeur_Q3 = False

print(f"Résultat Q3 : {valeur_Q3}")
# Out:
# Résultat Q3 : True

# %% [markdown]
# ### **Question 4 : nettoyage de chaîne (1.0 pt)**
# Corrigez la ligne d'affectation pour que `valeur_Q4` contienne la chaîne `'Terminologie'` (sans l'espace de début et le point de fin).

# %%
mot_sale = "  Terminologie. "

# CORRECTION REQUISE (LIGNE SUIVANTE)
valeur_Q4 = mot_sale.lower().strip('., ')

print(f"Résultat Q4 : '{valeur_Q4}'")
# Out:
# Résultat Q4 : 'terminologie'

# %% [markdown]
# ### **Question 5 : évaluation booléenne (choix multiple) (1.0 pt)**
# L'expression `bool(ma_variable)` retourne `False`. Que peut *uniquement* contenir `ma_variable` ?
# 1. `1`
# 2. `'False'`
# 3. `None`
# 4. `' '` (Chaîne avec un espace)

# %%
# Renseignez ici le numéro du choix (1, 2, 3 ou 4)
reponse_Q5 = 3
print(f"Résultat Q5 : Choix {reponse_Q5}")
# Out:
# Résultat Q5 : Choix 3

# %% [markdown]
# ---
# ## Partie 2 : listes et itération (5 Q - 5.0 pts)

# %% [markdown]
# ### **Question 6 : modification de liste (1.0 pt)**
# Corrigez l'erreur de méthode pour que `outils_tal` contienne `['tokenisation', 'lemme', 'segmentation']` (vous devez supprimer `'morphosyntaxe'` et ajouter `'segmentation'`).

# %%
outils_tal = ['tokenisation', 'lemme', 'morphosyntaxe']

# CORRECTION REQUISE
outils_tal.pop() # Erreur: remove prend l'élément, pop() prend l'index ou retire le dernier sans argument.
outils_tal.append('segmentation') # Erreur: add n'existe pas pour les listes.

valeur_Q6 = outils_tal
print(f"Résultat Q6 : {valeur_Q6}")
# Out:
# Résultat Q6 : ['tokenisation', 'lemme', 'segmentation']

# %% [markdown]
# ### **Question 7 : parcours avec condition (1.0 pt)**
# Corrigez la condition `if` pour calculer le nombre de mots dans la liste `mots_bruts` qui ont une longueur **strictement supérieure à 6 caractères**.

# %%
mots_bruts = ['alignement', 'corpus', 'traduction', 'python', 'lexique']
compteur = 0
for mot in mots_bruts:
    # CORRECTION REQUISE (LIGNE SUIVANTE)
    if len(mot) >6:
        compteur += 1

valeur_Q7 = compteur
print(f"Résultat Q7 : {valeur_Q7}")
# Out:
# Résultat Q7 : 3

# %% [markdown]
# ### **Question 8 : itération d'index erronée (1.0 pt)**
# Le code essaie de parcourir la liste en utilisant une variable qui ne représente pas l'élément. Corrigez la boucle `for` pour afficher la liste de mots en majuscules `['MACHINE', 'LEARNING', 'NLP']`.

# %%
mots_source = ['machine', 'learning', 'nlp']
resultat = []

# CORRECTION REQUISE (LIGNES SUIVANTE)
for mot in mots_source:
    resultat.append(mot.upper())

valeur_Q8 = resultat
print(f"Résultat Q8 : {valeur_Q8}")
# Out:
# Résultat Q8 : ['MACHINE', 'LEARNING', 'NLP']

# %% [markdown]
# ### **Question 9 : parcours inversé (1.0 pt)**
# Corrigez les paramètres de la fonction `range()` pour afficher les éléments de la liste `notes` en sens **inverse** (soit `[15, 12, 9]`).

# %%
notes = [9, 12, 15]
resultat_Q9 = []

# CORRECTION REQUISE (LIGNE SUIVANTE)
for i in range(len(notes)-1, -1, -1):
    resultat_Q9.append(notes[i])

valeur_Q9 = resultat_Q9
print(f"Résultat Q9 : {valeur_Q9}")
# Out:
# Résultat Q9 : [15, 12, 9]

# %% [markdown]
# ### **Question 10 : `IndexError` (1.0 pt)**
# Le code provoque un `IndexError`. Corrigez l'erreur de condition pour que la boucle affiche `[5, 4, 3, 2, 1]`.

# %%
# CORRECTIONS REQUISES (LIGNES SUIVANTES)
compteur = 5
resultat_Q10 = []

while compteur > 0:
    resultat_Q10.append(compteur)
    compteur -= 1

valeur_Q10 = resultat_Q10
print(f"Résultat Q10 : {valeur_Q10}")
# Out:
# Résultat Q10 : [5, 4, 3, 2, 1]

# %% [markdown]
# ---
# ## Partie 3 : dictionnaires et conditions (5 Q - 5.0 pts)

# %% [markdown]
# ### **Question 11 : accès sécurisé (1.0 pt)**
# Le dictionnaire `terminologie` ne contient pas la clé `'cible'`. Corrigez la ligne pour stocker la valeur par défaut `'inconnu'` dans `valeur_Q11`, en évitant le risque de `KeyError`.

# %%
terminologie = {'source': 'EN', 'domaine': 'TAL'}

# CORRECTION REQUISE (LIGNE SUIVANTE)
valeur_Q11 = terminologie .get('cible', "inconnu")

print(f"Résultat Q11 : {valeur_Q11}")
# Out:
# Résultat Q11 : inconnu

# %% [markdown]
# ### **Question 12 : Itération de Dictionnaire (1.0 pt)**
# Corrigez la ligne de la boucle `for` pour afficher le dictionnaire `frequences` correctement, en itérant sur les **paires clé-valeur**.

# %%
frequences = {'le': 2, 'chat': 1}
dictionnaire_a_afficher = {}

# CORRECTION REQUISE (LIGNE SUIVANTE)
for cle, valeur in frequences .items():
    dictionnaire_a_afficher[cle] = valeur

valeur_Q12 = dictionnaire_a_afficher
print(f"Résultat Q12 : {valeur_Q12}")
# Out:
# Résultat Q12 : {'le': 2, 'chat': 1}

# %% [markdown]
# ### **Question 13 : décompte de fréquence (Correction logique) (1.0 pt)**
# Le code provoque une `KeyError` s'il est exécuté. Corrigez la logique `if/else` pour qu'il calcule correctement la fréquence et retourne `{'talk': 2, 'is': 1, 'cheap': 1}`.

# %%
phrase = ['talk', 'is', 'cheap', 'talk']
freq = {}
for mot in phrase:
    if mot in freq.keys():
        freq[mot] += 1
    else:
        freq[mot] = 1

valeur_Q13 = freq
print(f"Résultat Q13 : {valeur_Q13}")
# Out:
# Résultat Q13 : {'talk': 2, 'is': 1, 'cheap': 1}

# %% [markdown]
# ### **Question 14 : logique conditionnelle (1.0 pt)**
# Corrigez la première ligne de sorte à déterminer la valeur finale de `valeur_Q14` à Vrai.

# %%
a, b, c = 5, 10, 15
valeur_Q14 = ''
if (a > 5) or (b == 10):
    valeur_Q14 = 'Vrai'
elif (c > 20) and (a < 10):
    valeur_Q14 = 'Presque'
else:
    valeur_Q14 = 'Faux'

print(f"Résultat Q14 : {valeur_Q14}")
# Out:
# Résultat Q14 : Vrai

# %% [markdown]
# ### **Question 15 : filtrage de dictionnaire (1.0 pt)**
# Corrigez la boucle pour créer le dictionnaire `longs_mots` contenant uniquement les paires où la **longueur du mot (clé) est supérieure à 3**.

# %%
lexique = {'le': 'det', 'TAL': 'nom', 'mot': 'nom', 'code': 'nom'}
longs_mots = {}
for mot, type_mot in lexique.items():
    # CORRECTION REQUISE (LIGNE SUIVANTE)
    if len(mot) >= 3:
        longs_mots[mot] = type_mot

valeur_Q15 = longs_mots
print(f"Résultat Q15 : {valeur_Q15}")
# Out:
# Résultat Q15 : {'TAL': 'nom', 'mot': 'nom', 'code': 'nom'}

# %% [markdown]
# ---
# ## Partie 4 : fonctions et modularité (10 Q - 10.0 pts)

# %% [markdown]
# ### **Question 16 : fonction simple (1.0 pt)**
# Corrigez la fonction `saluer_personne` pour qu'elle **retourne** (`return`) la chaîne `Bonjour, David` si elle est appelée avec `'David'` (actuellement elle ne retourne rien).

# %%
def saluer_personne(nom_personne):
    # CORRECTION REQUISE (LIGNE SUIVANTE)
    ch ="Bonjour, " + nom_personne
    return ch

valeur_Q16 = saluer_personne('David')
print(f"Résultat Q16 : {valeur_Q16}")
# Out:
# Résultat Q16 : Bonjour, David

# %% [markdown]
# ### **Question 17 : distinguer `print` et `return` (1.0 pt)**
# Corrigez de sorte à ce que la valeur de `valeur_Q17` soit bien le carré du paramètre après l'appel à la fonction ci-dessous.

# %%
def carre_et_return(nombre):
    #print(nombre ** 2)
    return nombre ** 2

valeur_Q17 = carre_et_return(4)
print(f"Résultat Q17 : {valeur_Q17}")
# Out:
# Résultat Q17 : 16

# %% [markdown]
# ### **Question 18 : portée du `return` (1.0 pt)**
# Corrigez la fonction pour qu'elle retourne la chaîne `analyse` pour le mot `corpus` (elle retourne actuellement 'court').

# %%
def analyser_mot(mot):
  if len(mot) >=6:
    return 'analyse'
  else:
    return 'court'

valeur_Q18 = analyser_mot('corpus') # 6 caractères
print(f"Résultat Q18 : {valeur_Q18}")
# Out:
# Résultat Q18 : analyse

# %% [markdown]
# ### **Question 19 : modularité (1.0 pt)**
# Déterminez la valeur finale de `valeur_Q19` à `nltk`en suivant l'exécution des fonctions imbriquées et construisant/complétant leur traitement propre à leur dénomination.

# %%
def minuscules(texte):
    return texte .lower()
def enlever_ponctuation(texte_sale):
    return texte_sale .strip('.,;!:?')

valeur_Q19 = enlever_ponctuation(minuscules('NLTK.'))
print(f"Résultat Q19 : {valeur_Q19}")
# Out:
# Résultat Q19 : nltk

# %% [markdown]
# ### **Question 20 : retour de dictionnaire (1.0 pt)**
# Corrigez la fonction pour qu'elle retourne un dictionnaire contenant les informations exactes : `{'longueur': 7, 'minuscules': 'termino'}` pour le mot `'Termino'`.

# %%
def analyser_infos(mot):
    return {
        'longueur': len(mot), #
        'minuscules': mot.lower()
    }

valeur_Q20 = analyser_infos('Termino')


valeur_Q20 = analyser_infos('Termino')
print(f"Résultat Q20 : {valeur_Q20}")
# Out:
# Résultat Q20 : {'longueur': 7, 'minuscules': 'termino'}

# %% [markdown]
# ### **Question 21 : arguments par défaut (Choix multiple) (1.0 pt)**
# Étant donné `def f(x, y=10): return x + y`, que retourne l'appel `f(5)`?
# 1. `5`
# 2. `10`
# 3. `15`
# 4. `TypeError`

# %%
# Renseignez ici le numéro du choix (1, 2, 3 ou 4)
reponse_Q21 = 3
print(f"Résultat Q21 : Choix {reponse_Q21}")
# Out:
# Résultat Q21 : Choix 3

# %% [markdown]
# ### **Question 22 : argument manquant (Correction) (1.0 pt)**
# L'appel à la fonction provoque une `TypeError` car un argument est manquant. Corrigez la fonction pour qu'elle puisse être appelée sans le paramètre `b` et retourne `15` à l'appel `addition(5)`.

# %%
def addition(a, b=10):
    return a + b

# CORRECTION REQUISE (MODIFIEZ LA FONCTION CI-DESSUS pour donner une valeur par défaut à b)
valeur_Q22 = addition(10)
print(f"Résultat Q22 : {valeur_Q22}")
# Out:
# Résultat Q22 : 20

# %% [markdown]
# ### **Question 23 : portée des variables (1.0 pt)**
# Déterminez la valeur retournée par le code ci-dessous.
# ```python
# def calculer(x):
#     return x * 2
# y = 5
# resultat = calculer(y)
# ```

# %%
# Renseignez ici la valeur de 'resultat' qui serait retournée. (Nombre)
reponse_Q23 = 10
print(f"Résultat Q23 : {reponse_Q23}")
# Out:
# Résultat Q23 : 10

# %% [markdown]
# ### **Question 24 : Boucle `while` (Correction logique) (1.0 pt)**
# Corrigez la boucle `while` pour qu'elle s'arrête **exactement** après avoir exécuté 5 fois la ligne `i += 1`, ce qui doit laisser `i` à 5.

# %%
i = 0
while i < 10: # ne pas modifier cette ligne
    i += 1
    if i == 5:
        break

valeur_Q24 = i
print(f"Résultat Q24 : {valeur_Q24}")
# Out:
# Résultat Q24 : 5

# %% [markdown]
# ### **Question 25 : modularité (Correction + Renseignement) (1.0 pt)**
# La fonction `nettoyer_mot_av` doit retirer **uniquement** la ponctuation `'`, `.` et `,` du **début et de la fin** du mot, et le convertir en **minuscules**. Corrigez-la pour que `'L'analyse,'` retourne `'l'analyse'`.

# %%
def nettoyer_mot_av(mot):
    mot = mot.lower()
    return mot.strip(",.!")

# CORRECTION REQUISE (MODIFIEZ LA FONCTION CI-DESSUS)
valeur_Q25 = nettoyer_mot_av("L'analyse,")
print(f"Résultat Q25 : {valeur_Q25}")
# Out:
# Résultat Q25 : l'analyse

# %% [markdown]
# ---
# ## Partie 5 : Synthèse, Algorithmique Avancée et Fichiers (5 Q - 9.0 pts)

# %% [markdown]
# ### **Question 26 : séparer par Casse (Correction Logique) (2.0 pts)**
# Corrigez la logique du `if` pour séparer les mots : `avec_majuscule` (si le mot contient au moins une majuscule) et `sans_majuscule`. Le résultat attendu est `{'avec': ['Python', 'TAL', 'Nlp'], 'sans': ['code', 'texte']}`.

# %%
mots_source = ['Python', 'code', 'TAL', 'texte', 'Nlp']
avec_majuscule, sans_majuscule = [], []

for mot in mots_source:
    # CORRECTION REQUISE (LIGNE SUIVANTE - Logique erronée)
    if mot.lower() != mot:
        avec_majuscule.append(mot)
    else:
        sans_majuscule.append(mot)

valeur_Q26 = {'avec': avec_majuscule, 'sans': sans_majuscule}
print(f"Résultat Q26 : {valeur_Q26}")
# Out:
# Résultat Q26 : {'avec': ['Python', 'TAL', 'Nlp'], 'sans': ['code', 'texte']}

# %% [markdown]
# ### **Question 27 : Création de Dictionnaire (2.0 pts)**
# Créez un dictionnaire `valeur_Q27` où les clés sont les mots de `mots` et les valeurs sont leurs **longueurs** respectives, en utilisant la méthode de votre choix (boucle `for` ou compréhension).

# %%
mots = ['phrase', 'texte', 'mot']
valeur_Q27 = {} # Doit être {'phrase': 6, 'texte': 5, 'mot': 3}

for mot in mots:
  valeur_Q27 [mot] = len(mot)

print(f"Résultat Q27 : {valeur_Q27}")
# Out:
# Résultat Q27 : {'phrase': 6, 'texte': 5, 'mot': 3}

# %% [markdown]
# ### **Question 28 : traducteur Mot à Mot (2.0 pts)**
# Le traducteur est incomplet. Complétez la fonction `traduire_mot` pour qu'elle **retourne** la traduction si la clé est dans le `lexique`. Sinon, elle doit retourner le mot original **en minuscules** (comme si le nettoyage était incomplet).

# %%
lexique = {'book': 'livre', 'dog': 'chien'}

def traduire_mot(mot, lexique):
    if mot in lexique .keys():
      return lexique [mot]
    else:
      return mot .lower()
    # CODE À COMPLÉTER ICI (Utiliser if/else et return)


# Test : doit retourner ['chien', 'cat']
traduction_1 = traduire_mot('dog', lexique)
traduction_2 = traduire_mot('CAT', lexique)

valeur_Q28 = [traduction_1, traduction_2]
print(f"Résultat Q28 : {valeur_Q28}")
# Out:
# Résultat Q28 : ['chien', 'cat']

# %% [markdown]
# ### **Question 29 : synthèse de traitement (Correction logique) (2.0 pts)**
# La fonction `analyser_phrase` doit retourner un dictionnaire contenant une liste de `mots_nettoyés` (`['le', 'tal', 'est', 'cool']`) et le `nb_caracteres` **total de la phrase originale** (avec espaces et ponctuation). Corrigez les erreurs de calcul (`nb_caracteres` et `mots_nettoyés`).

# %%
phrase = "Le TAL est cool."
ponctuation_a_enlever = ".,!? "

def nettoyer_mot_simple(mot):
    # La fonction est correcte ici si la ponctuation est un tuple de 4 éléments.
    mot = mot.lower()
    return mot.strip(ponctuation_a_enlever)

def analyser_phrase(phrase):
    mots = phrase.split()
    mots_nettoyés = [nettoyer_mot_simple(mot) for mot in mots]

    # CORRECTION REQUISE (LIGNES SUIVANTES)
    nb_caracteres = len(phrase)

    # CORRECTION REQUISE (LIGNE SUIVANTE)
    # Assurez-vous qu'il n'y a pas de chaîne vide si le split() a laissé un espace.
    mots_nettoyés = [mot for mot in mots_nettoyés if mot] # Code à ajouter/corriger

    return {
        'mots_nettoyés': mots_nettoyés,
        'nb_caracteres': len(phrase)
    }

valeur_Q29 = analyser_phrase(phrase)
print(f"Résultat Q29 : {valeur_Q29}")
# Out:
# Résultat Q29 : {'mots_nettoyés': ['le', 'tal', 'est', 'cool'], 'nb_caracteres': 16}

# %% [markdown]
# ### **Question 30 : Fichier et Statistiques (Lecture) (1.0 pt)**
# Corrigez le code pour qu'il calcule correctement le **nombre de lignes** et le **nombre de mots** du contenu simulé. L'erreur vient du fait que `split()` sur un texte complet ne compte pas les lignes de la même manière que `split(' ')` compte les mots.

# %%
# Contenu simulé du fichier (vous devez le traiter comme si vous veniez de le lire avec f.read()):
contenu_simule = "Première ligne de texte.\nDeuxième ligne.\nTroisième ligne."

try:
    texte_complet = contenu_simule

    # CORRECTION REQUISE (LIGNE SUIVANTE)
    nb_lignes = len(texte_complet.split('\n'))
    nb_mots = len(texte_complet.split())

except Exception as e:
    nb_lignes = -1
    nb_mots = -1

valeur_Q30 = {'lignes': nb_lignes, 'mots': nb_mots}
print(f"Résultat Q30 : {valeur_Q30}")
# Out:
# Résultat Q30 : {'lignes': 3, 'mots': 8}
