# %% [markdown]
# # Contrôle Final S2 : Algorithmique et Fichiers
#
# **Durée :** 1h30
# **Nombre de questions :** 18
# **Consignes :**
# * Ce devoir évalue l'ensemble des compétences du semestre.
# * **Interdiction d'utiliser les Regex**.
# * Exécutez la **Partie 0** pour générer les données.

# %%
# --- IDENTIFICATION ---
nom = "NON_RENSEIGNE"
prenom = "NON_RENSEIGNE"
classe = "M1-TILT"

# %% [markdown]
# ## Partie 0 : Génération des Données (Exécuter 1 fois)

# %%
strophes = [
    "La Nature est un temple où de vivants piliers",
    "Laissent parfois sortir de confuses paroles;",
    "L'homme y passe à travers des forêts de symboles",
    "Qui l'observent avec des regards familiers.",
    "",
    "Comme de longs échos qui de loin se confondent",
    "Dans une ténébreuse et profonde unité,",
    "Vaste comme la nuit et comme la clarté,",
    "Les parfums, les couleurs et les sons se répondent.",
    "   "
]
contenu = []
for i in range(60): # 600 lignes
    for ligne in strophes:
        if i % 3 == 0: ligne = ligne.upper()
        contenu.append(ligne)
with open("corpus_litterature.txt", "w", encoding="utf-8") as f:
    f.write("\n".join(contenu))
print("Données générées.")

# %% [markdown]
# ## Partie 1 : Algorithmique et Structures (5 pts)
# Révisions sur les listes, dictionnaires et compréhensions.

# %%
# Q1 : Liste des nombres de 0 à 50 divisibles par 3 mais PAS par 9.
reponse_Q1 = []
# Code ici
print("Q1 :", reponse_Q1)

# %%
# Q2 : Filtrage de mots longs
mots_test = ["chat", "anticonstitutionnel", "table", "programmation", "riz"]
# Gardez uniquement les mots de plus de 10 caractères.
reponse_Q2 = []
# Code ici
print("Q2 :", reponse_Q2)

# %%
# Q3 : Fusion de dictionnaires (Somme des valeurs)
d1 = {'a': 10, 'b': 20, 'c': 30}
d2 = {'b': 5, 'c': 10, 'd': 40}
reponse_Q3 = {}
# Code ici
print("Q3 :", reponse_Q3)

# %%
# Q4 : Extraction de clés
scores = {'Paul': 12, 'Jean': 8, 'Marie': 15, 'Pierre': 9}
# Créez la liste des noms ayant la moyenne (>= 10).
reponse_Q4 = []
# Code ici
print("Q4 :", reponse_Q4)

# %%
# Q5 : Similarité de Jaccard (Intersection / Union)
set_A = {1, 2, 3, 4}
set_B = {3, 4, 5, 6}
reponse_Q5 = 0.0
# Code ici
print("Q5 :", reponse_Q5)

# %% [markdown]
# ## Partie 2 : Lecture et Analyse de Fichiers (5 pts)

# %%
# Q6 : Nombre total de lignes du fichier 'corpus_litterature.txt'
reponse_Q6 = 0
# Code ici
print("Q6 :", reponse_Q6)

# %%
# Q7 : Nombre de lignes NON vides (contenant du texte)
reponse_Q7 = 0
# Code ici
print("Q7 :", reponse_Q7)

# %%
# Q8 : Extraction
# Comptez le nombre de lignes contenant le mot "PARFUMS" (peu importe la casse : Parfums, parfums, PARFUMS...)
reponse_Q8 = 0
# Code ici
print("Q8 :", reponse_Q8)

# %%
# Q9 : Lecture partielle
# Lisez et stockez les 50 premiers caractères du fichier.
reponse_Q9 = ""
# Code ici
print("Q9 :", reponse_Q9)

# %% [markdown]
# ## Partie 3 : Nettoyage et Ressources (6 pts)

# %%
# Q10 : Fonction de nettoyage
# Créez une fonction clean(txt) qui met en minuscules et remplace ",;:.?!" par des espaces.
def clean(txt):
    return txt

reponse_Q10 = clean("Salut; ça va?!")
print("Q10 :", reponse_Q10)

# %%
# Q11 : Tokenisation complète
# Lisez le fichier, nettoyez chaque ligne, découpez en mots.
# Stockez TOUS les mots dans une liste 'all_tokens'.
all_tokens = []
# Code ici
print("Q11 (total mots) :", len(all_tokens))

# %%
# Q12 : Suppression des Stopwords
stopwords = {'le', 'la', 'les', 'de', 'des', 'un', 'une', 'et', 'en', 'dans', 'l', 'd', 'qu', 'à'}
# Filtrez 'all_tokens' pour créer 'tokens_utiles' sans ces mots.
tokens_utiles = []
# Code ici
reponse_Q12 = len(tokens_utiles)
print("Q12 (mots utiles) :", reponse_Q12)

# %%
# Q13 : Fréquences
# Créez le dictionnaire {mot: occurrence} à partir de 'tokens_utiles'.
freq = {}
# Code ici
reponse_Q13 = freq.get('nature', 0)
print("Q13 (freq 'nature') :", reponse_Q13)

# %%
# Q14 : Le mot le plus fréquent
# Trouvez le mot qui apparait le plus souvent dans 'tokens_utiles'.
reponse_Q14 = ""
# Code ici
print("Q14 :", reponse_Q14)

# %% [markdown]
# ## Partie 4 : Écriture et Sauvegarde (4 pts)

# %%
# Q15 : Export CSV trié
# Sauvegardez le dictionnaire freq dans 'stats.csv' (Mot;Freq).
# Triez les lignes par fréquence décroissante.
# Code écriture ici

# Vérif (lecture 1ère ligne)
try:
    with open('stats.csv', 'r') as f: reponse_Q15 = f.readline().strip()
except: reponse_Q15 = ""
print("Q15 :", reponse_Q15)

# %%
# Q16 : Sous-corpus filtré
# Créez 'corpus_L.txt' contenant uniquement les lignes originales commençant par 'L'.
# Code écriture ici

# Vérif (nombre lignes)
try:
    with open('corpus_L.txt', 'r') as f: reponse_Q16 = len(f.readlines())
except: reponse_Q16 = 0
print("Q16 :", reponse_Q16)

# %%
# Q17 : Statistiques de longueur
# Créez un fichier 'longueurs.csv'.
# Pour chaque longueur de mot (1 lettre, 2 lettres...), indiquez combien de mots ont cette longueur dans 'tokens_utiles'.
# Ex: 5;120 (il y a 120 mots de 5 lettres)
# Code ici

# Vérif (lecture tout le fichier)
reponse_Q17 = []
try:
    with open('longueurs.csv', 'r') as f: reponse_Q17 = [l.strip() for l in f]
except: pass
print("Q17 :", reponse_Q17)

# %%
# Q18 : Copie de sauvegarde
# Copiez simplement le fichier 'corpus_litterature.txt' vers 'backup.txt'.
# Code ici

# Vérif (existence)
import os
reponse_Q18 = os.path.exists('backup.txt')
print("Q18 :", reponse_Q18)
