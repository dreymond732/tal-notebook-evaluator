# %% [markdown]
# # TD0 S3 — Diagnostic : du texte brut aux tokens
#
# Objectif : vérifier les acquis Python nécessaires au début du parcours TAL.
#
# Ce TD est formatif. Exécutez chaque cellule d'essai : le correcteur lit les sorties enregistrées, il n'exécute jamais votre code.

# %%
from pathlib import Path
texte_exemple = """Le traitement automatique du langage analyse des textes.
Les mots, la ponctuation et les formes linguistiques comptent."""
Path("corpus_td0.txt").write_text(texte_exemple, encoding="utf-8")

# %% [markdown]
# ## Exercice 1 — Lire et observer
# Remplacez la variable ci-dessous par le contenu du fichier fourni lorsque vous travaillerez sur un document externe. Affichez le nombre de caractères avec le marqueur demandé.

# %%
# À compléter : lisez corpus_td0.txt en UTF-8 dans la variable texte, puis affichez son nombre de caractères.
# print("Résultat Q1 :", ...)

# %% [markdown]
# ## Exercice 2 — Découpage brut
# Créez une variable `mots` contenant `texte.split()`. Affichez la liste.

# %%
# À compléter
# print("Résultat Q2 :", mots)

# %% [markdown]
# ## Exercice 3 — Compter
# Affichez le nombre d'éléments de `mots`.

# %%
# À compléter
# print("Résultat Q3 :", ...)

# %% [markdown]
# ## Exercice 4 — Interpréter
# Dans une cellule de code, écrivez un commentaire expliquant au moins une limite de `split()` : ponctuation, casse, contraction ou morphologie. Puis affichez une phrase commençant par `Résultat Q4 :`.

# %%
# Votre commentaire ici
# print("Résultat Q4 : ...")

# %% [markdown]
# ### Bilan
# - 4/4 : prêt pour TD1 ;
# - 2–3/4 : réalisez R0 avant TD1 ;
# - 0–1/4 : R0 est prioritaire et nous reprendrons les bases au début du TD1.
