# %% [markdown]
# # TD2 S3 — Analyse de corpus réutilisable
#
# Objectif : construire une fonction paramétrée qui compte les lemmes nominaux pertinents, puis interpréter le résultat.

# %%
# !pip install -q spacy==3.8.7 fr_core_news_sm==3.8.0
from collections import Counter
import spacy
nlp = spacy.load("fr_core_news_sm")

corpus = """Les systèmes de traduction traitent des corpus. Un corpus contient des textes,
des formes répétées et des termes qui peuvent être pertinents dans un contexte donné."""

# %% [markdown]
# ## Exercice 1 — Fonction de fréquences
# Écrivez `frequences_lemmas(texte, stopwords=None)`. Elle doit :
# - traiter le texte avec `nlp` ;
# - ne conserver que les noms ;
# - compter leurs lemmes ;
# - exclure les stopwords de spaCy et ceux fournis en argument ;
# - retourner un `Counter`.

# %%
# À compléter

# %% [markdown]
# ## Exercice 2 — Essai et interprétation
# Appelez votre fonction. Affichez les cinq lemmes les plus fréquents. Expliquez en commentaire si cette liste suffit à identifier les termes importants.

# %%
# À compléter

# %% [markdown]
# ## Exercice 3 — Comparaison
# Ajoutez une liste de mots à écarter adaptée à ce corpus. Comparez le résultat brut et filtré.

# %%
# À compléter

# %% [markdown]
# ### À retenir
# La fréquence est une première observation, pas une preuve de pertinence. Le filtrage est un choix d'analyse qui doit être explicité.
