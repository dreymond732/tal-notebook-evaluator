# %% [markdown]
# # R1 S3 — Parcourir un Doc spaCy
#
# Durée indicative : 25 minutes. À terminer avant TD2. Le correcteur est disponible sous « R1 S3 ».

# %%
# !pip install -q spacy==3.8.7 fr_core_news_sm==3.8.0
import spacy
nlp = spacy.load("fr_core_news_sm")
texte = "Les traducteurs analysent rapidement les nouveaux documents."

# %% [markdown]
# ## 1. Observer le document
# Construisez d'abord `doc = nlp(texte)`, puis affichez le nombre de tokens.

# %%
# À compléter
# print("Résultat Q1 :", len(doc))

# %% [markdown]
# ## 2. Parcourir
# Affichez chaque token avec son lemme et son POS.

# %%
# À compléter
# print("Résultat Q2 : terminé")

# %% [markdown]
# ## 3. Noms
# Construisez et affichez la liste des lemmes des noms.

# %%
# À compléter
# print("Résultat Q3 :", noms)

# %% [markdown]
# ## 4. Verbes
# Construisez et affichez la liste des lemmes des verbes.

# %%
# À compléter
# print("Résultat Q4 :", verbes)
