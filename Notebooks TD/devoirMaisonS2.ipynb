# %% [markdown]
# # Devoir maison intermédiaire d'approfondissement
# ## Partie 0 : identification
# Remplissez la cellule ci-dessous avec vos informations.

# %%
nom = "..."
prenom = "..."
classe = "..."

# %% [markdown]
# ## Partie 1 : révisions des bases (20 pts)
# Remplissez les variables `reponse_QX` pour obtenir les résultats attendus.

# %%
# Q1: Slicing: extrayez 'bon' de 'bonjour'.
mot = 'bonjour'
reponse_Q1 = None
print(f"Résultat Q1 : {reponse_Q1}")

# %%
# Q2: Ajoutez 4 à la liste [1, 2, 3].
l = [1, 2, 3]
# CORRECTION REQUISE
reponse_Q2 = l
print(f"Résultat Q2 : {reponse_Q2}")

# %%
# Q3: Récupérez le dernier élément de [1, 2, 3].
l = [1, 2, 3]
reponse_Q3 = None
print(f"Résultat Q3 : {reponse_Q3}")

# %%
# Q4: Récupérez la valeur de 'age'.
d = {'nom': 'A', 'age': 20}
reponse_Q4 = None
print(f"Résultat Q4 : {reponse_Q4}")

# %%
# Q5: Ajoutez 'ville': 'Paris' au dictionnaire.
d = {'nom': 'A', 'age': 20}
# CORRECTION REQUISE
reponse_Q5 = d
print(f"Résultat Q5 : {reponse_Q5}")

# %%
# Q6: Calculez la somme de [1, 2, 3].
l = [1, 2, 3]
reponse_Q6 = None
print(f"Résultat Q6 : {reponse_Q6}")

# %%
# Q7: Mettez 'test' en majuscules.
mot = 'test'
reponse_Q7 = None
print(f"Résultat Q7 : {reponse_Q7}")

# %%
# Q8: Remplacez 'chat' par 'chien' dans 'mon chat'.
phrase = 'mon chat'
reponse_Q8 = None
print(f"Résultat Q8 : {reponse_Q8}")

# %%
# Q9: Trouvez la longueur de la liste.
l = [1, 2, 3, 4, 5]
reponse_Q9 = None
print(f"Résultat Q9 : {reponse_Q9}")

# %%
# Q10: Créez un set des éléments uniques.
l = [1, 1, 2, 2]
reponse_Q10 = None
print(f"Résultat Q10 : {reponse_Q10}")

# %%
# Q11: Vérifiez si 10 est strictement supérieur à 5.
reponse_Q11 = None
print(f"Résultat Q11 : {reponse_Q11}")

# %%
# Q12: Séparez 'a-b-c' en liste avec le délimiteur '-'.
chaine = 'a-b-c'
reponse_Q12 = None
print(f"Résultat Q12 : {reponse_Q12}")

# %%
# Q13: Concaténez [1] et [2].
reponse_Q13 = None
print(f"Résultat Q13 : {reponse_Q13}")

# %%
# Q14: Valeur absolue de -5.
reponse_Q14 = None
print(f"Résultat Q14 : {reponse_Q14}")

# %%
# Q15: Maximum de [1, 9, 3].
l = [1, 9, 3]
reponse_Q15 = None
print(f"Résultat Q15 : {reponse_Q15}")

# %%
# Q16: Convertissez la chaîne '42' en entier.
chaine = '42'
reponse_Q16 = None
print(f"Résultat Q16 : {reponse_Q16}")

# %%
# Q17: Arrondissez 3.14159 à 2 décimales.
pi = 3.14159
reponse_Q17 = None
print(f"Résultat Q17 : {reponse_Q17}")

# %%
# Q18: Vérifiez (booléen) si 2 est dans [1, 2, 3].
l = [1, 2, 3]
reponse_Q18 = None
print(f"Résultat Q18 : {reponse_Q18}")

# %%
# Q19: Récupérez la liste (list) des clés du dictionnaire.
d = {'a': 1}
reponse_Q19 = None
print(f"Résultat Q19 : {reponse_Q19}")

# %%
# Q20: Récupérez la liste (list) des valeurs du dictionnaire.
d = {'a': 1}
reponse_Q20 = None
print(f"Résultat Q20 : {reponse_Q20}")

# %% [markdown]
# ## Partie 2 : algorithmique avancée (20 pts)

# %%
# Q21: Compréhension: liste des carrés de 1 à 5 inclus.
reponse_Q21 = None
print(f"Résultat Q21 : {reponse_Q21}")

# %%
# Q22: Compréhension: dictionnaire associant x à x**2 pour x dans [1, 2, 3].
reponse_Q22 = None
print(f"Résultat Q22 : {reponse_Q22}")

# %%
# Q23: Filtrez les nombres pairs de la liste avec une compréhension.
l = [1, 2, 3, 4]
reponse_Q23 = None
print(f"Résultat Q23 : {reponse_Q23}")

# %%
# Q24: Aplatissez [[1, 2], [3, 4]] avec des boucles imbriquées.
matrice = [[1, 2], [3, 4]]
reponse_Q24 = []
# CORRECTION REQUISE
print(f"Résultat Q24 : {reponse_Q24}")

# %%
# Q25: Comptez les fréquences des lettres dans 'abac'.
mot = 'abac'
reponse_Q25 = {}
# CORRECTION REQUISE
print(f"Résultat Q25 : {reponse_Q25}")

# %%
# Q26: Zippez ['a', 'b'] et [1, 2] pour former un dictionnaire.
k = ['a', 'b']
v = [1, 2]
reponse_Q26 = None
print(f"Résultat Q26 : {reponse_Q26}")

# %%
# Q27: Inversez clés/valeurs du dictionnaire.
d = {'a': 1, 'b': 2}
reponse_Q27 = {}
# CORRECTION REQUISE
print(f"Résultat Q27 : {reponse_Q27}")

# %%
# Q28: Transposez la matrice (les lignes deviennent des colonnes).
mat = [[1, 2], [3, 4]]
reponse_Q28 = []
# CORRECTION REQUISE
print(f"Résultat Q28 : {reponse_Q28}")

# %%
# Q29: Trouvez les éléments communs aux deux listes.
l1 = [1, 2, 3]
l2 = [2, 3, 4]
reponse_Q29 = None
print(f"Résultat Q29 : {reponse_Q29}")

# %%
# Q30: Calculez la factorielle 5*4*3*2*1 de 5 avec une boucle.
n = 5
reponse_Q30 = 1
# CORRECTION REQUISE
print(f"Résultat Q30 : {reponse_Q30}")
