# %% [markdown]
# # TD2 S1 — Chaînes et séquences
#
# ## Objectif de la séance
#
# Transformer une chaîne, accéder à ses éléments et utiliser `split()` / `join()` pour une première manipulation de texte.

# %% [markdown]
# Travaillez dans l’ordre des cellules. Après chaque exercice, exécutez la cellule et conservez l’affichage demandé.

# %%
nom = "..."
prenom = "..."
classe = "..."

# %% [markdown]
# ## Rappel — Les chaînes
#
# Une chaîne est une séquence ordonnée et non modifiable. Elle peut être indexée, découpée et transformée par des méthodes qui renvoient une nouvelle chaîne.

# %%
texte_brut = "   Le TAL transforme des textes.   "
# Q1 — retirez les espaces de bord dans texte_propre
# print("Résultat Q1 :", texte_propre)

# %%
# Q2 — mettez texte_propre en minuscules et remplacez "textes" par "corpus"
# print("Résultat Q2 :", texte_transforme)

# %% [markdown]
# ## Exercice 3 — Indexer puis découper
#
# Avec `mot = "tokenisation"`, récupérez le premier caractère, le dernier caractère et la tranche allant de l’indice 0 à l’indice 4 exclu.

# %%
mot = "tokenisation"
# Q3
# print("Résultat Q3 :", premier, dernier, debut)

# %% [markdown]
# ## Exercice 4 — Découpage
#
# Découpez `phrase` avec `split()`. Affichez la liste puis le troisième élément.

# %%
phrase = "La traduction automatique aide parfois"
# Q4
# print("Résultat Q4 :", tokens, tokens[2])

# %% [markdown]
# ## Exercice 5 — Reconstruction
#
# À partir de `tokens`, construisez `phrase_avec_barres` avec `join()` et le séparateur ` | `.

# %%
# Q5
# print("Résultat Q5 :", phrase_avec_barres)

# %% [markdown]
# ## Exercice 6 — Deux nettoyages, deux essais
#
# Pour chacune des chaînes de `exemples`, retirez les espaces de bord et passez en minuscules. Stockez les résultats dans une nouvelle liste.

# %%
exemples = ["  Bonjour  ", "TAL", "  Corpus Français"]
# Q6
# print("Résultat Q6 :", exemples_nettoyes)

# %% [markdown]
# ## Exercice 7 — Interpréter une limite
#
# Testez `split()` sur la chaîne `"L’analyse, c’est utile !"`. En une phrase, expliquez dans `commentaire` une limite du découpage par espaces.

# %%
# Q7
# print("Résultat Q7 :", commentaire)
