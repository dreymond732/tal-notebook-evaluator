# %% [markdown]
# # TD3 S1 — Collections : listes, dictionnaires et ensembles
#
# ## Objectif de la séance
#
# Choisir et manipuler une structure de données appropriée pour représenter des mots, un lexique ou un vocabulaire.

# %% [markdown]
# Travaillez dans l’ordre des cellules. Après chaque exercice, exécutez la cellule et conservez l’affichage demandé.

# %%
nom = "..."
prenom = "..."
classe = "..."

# %% [markdown]
# ## Rappel — Choisir une collection
#
# Une liste conserve un ordre et peut être modifiée. Un tuple est ordonné mais non modifiable. Un dictionnaire associe des clés à des valeurs. Un ensemble ne conserve que des éléments uniques.

# %%
outils = ["corpus", "lexique", "concordancier"]
# Q1 — ajoutez "tokeniseur", retirez le dernier élément, puis affichez la liste restante
# print("Résultat Q1 :", outils)

# %% [markdown]
# ## Exercice 2 — Liste ou tuple ?
#
# Créez le tuple `langues_romanes` contenant français, italien et espagnol. Vérifiez son type, puis expliquez dans `choix_tuple` pourquoi cette collection convient à une liste de référence stable.

# %%
# Q2
# print("Résultat Q2 :", type(langues_romanes), choix_tuple)

# %% [markdown]
# ## Exercice 3 — Lexique bilingue
#
# Créez un dictionnaire `lexique` avec les traductions de `book`, `language` et `data`. Ajoutez ensuite `corpus` puis affichez la traduction de `language`.

# %%
# Q3
# print("Résultat Q3 :", lexique["language"])

# %% [markdown]
# ## Exercice 4 — Parcourir un dictionnaire
#
# Parcourez `lexique.items()` et construisez une liste `entrees_lexique` de chaînes sous la forme `anglais -> français`.

# %%
# Q4
# print("Résultat Q4 :", entrees_lexique)

# %% [markdown]
# ## Exercice 5 — Formes distinctes
#
# Transformez la liste `formes` en un ensemble nommé `vocabulaire`. Affichez le nombre de formes et le nombre de formes distinctes.

# %%
formes = ["texte", "corpus", "texte", "donnée", "corpus", "analyse"]
# Q5
# print("Résultat Q5 :", len(formes), len(vocabulaire))

# %% [markdown]
# ## Exercice 6 — Comparer deux vocabulaires
#
# Construisez les ensembles correspondant aux deux listes, puis calculez les termes communs et les termes présents seulement dans le premier corpus.

# %%
corpus_a = ["texte", "analyse", "langue", "corpus"]
corpus_b = ["langue", "corpus", "modèle"]
# Q6
# print("Résultat Q6 :", communs, seulement_a)
